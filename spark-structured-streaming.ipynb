# %% [markdown]
# ## 4. Real‑Time Processing with Spark Structured Streaming
# Launch a Spark session that reads from the Kafka topic and processes the data. This code is placed in another Jupyter cell (or a separate notebook):

# %%
#pip install pyspark kafka-python

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json, col, when, unix_timestamp, to_timestamp
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType
import requests
import redis
import json

# 🔥 Initialize Spark with Kafka Support
spark = SparkSession.builder \
    .appName("NYC_Taxi_Streaming") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.0") \
    .getOrCreate()

# ✅ Define Schema for Kafka Data (Includes `taxi_type`)
schema = StructType([
    StructField("vendorid", IntegerType()),
    StructField("pickup_datetime", StringType()),
    StructField("dropoff_datetime", StringType()),
    StructField("passenger_count", IntegerType()),
    StructField("trip_distance", DoubleType()),
    StructField("fare_amount", DoubleType()),
    StructField("extra", DoubleType()),
    StructField("mta_tax", DoubleType()),
    StructField("tip_amount", DoubleType()),
    StructField("tolls_amount", DoubleType()),
    StructField("improvement_surcharge", DoubleType()),
    StructField("total_amount", DoubleType()),
    StructField("table_name", StringType()),
    StructField("taxi_type", StringType())  # ✅ Added taxi_type
])

# ✅ Read Data from Kafka
stream_df = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", "nyc_taxi_topic") \
    .option("startingOffsets", "earliest") \
    .load()

# ✅ Parse Kafka JSON Data
parsed_df = stream_df.select(
    from_json(col("value").cast("string"), schema).alias("data")
).select("data.*")

# ✅ Convert `pickup_datetime` and `dropoff_datetime` to timestamp format
parsed_df = parsed_df.withColumn("pickup_datetime", to_timestamp(col("pickup_datetime"), "yyyy-MM-dd HH:mm:ss")) \
                     .withColumn("dropoff_datetime", to_timestamp(col("dropoff_datetime"), "yyyy-MM-dd HH:mm:ss"))

# ✅ Compute Trip Duration (in Minutes)
trip_duration_expr = (unix_timestamp(col("dropoff_datetime")) - unix_timestamp(col("pickup_datetime"))) / 60

parsed_df = parsed_df.withColumn(
    "trip_duration",
    when(trip_duration_expr > 0, trip_duration_expr).otherwise(0.0)  # ✅ Only compute trip_duration once
)

# ✅ Compute Tip Ratio, Toll Ratio, and Fare Per Mile/Passenger
parsed_df = parsed_df.withColumn(
    "tip_ratio", when(col("total_amount") > 0, col("tip_amount") / col("total_amount")).otherwise(0.0)
).withColumn(
    "toll_ratio", when(col("total_amount") > 0, col("tolls_amount") / col("total_amount")).otherwise(0.0)
).withColumn(
    "fare_per_mile", when(col("trip_distance") > 0, col("fare_amount") / col("trip_distance")).otherwise(0.0)
).withColumn(
    "fare_per_passenger", when(col("passenger_count") > 0, col("fare_amount") / col("passenger_count")).otherwise(0.0)
)

# ✅ Compute Duration per Mile & Duration per Passenger
parsed_df = parsed_df.withColumn(
    "duration_per_mile", 
    when((col("trip_distance") > 0) & (col("trip_duration") > 0), col("trip_duration") / col("trip_distance")).otherwise(0.0)
).withColumn(
    "duration_per_passenger", 
    when((col("passenger_count") > 0) & (col("trip_duration") > 0), col("trip_duration") / col("passenger_count")).otherwise(0.0)
)
# Out:
# 25/03/22 21:40:59 WARN Utils: Your hostname, Sherines-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.0.101 instead (on interface en0)
# 25/03/22 21:40:59 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Ivy Default Cache set to: /Users/sherinechally/.ivy2/cache
# The jars for the packages stored in: /Users/sherinechally/.ivy2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-5f12a508-8efc-4ca7-ad80-bd774fa17858;1.0
# 	confs: [default]
# :: loading settings :: url = jar:file:/opt/anaconda3/envs/py39/lib/python3.9/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.5.0 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.5.0 in central
# 	found org.apache.kafka#kafka-clients;3.4.1 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.3 in central
# 	found org.slf4j#slf4j-api;2.0.7 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.4 in central
# 	found org.apache.hadoop#hadoop-client-api;3.3.4 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
# :: resolution report :: resolve 208ms :: artifacts dl 5ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	org.apache.commons#commons-pool2;2.11.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.3.4 from central in [default]
# 	org.apache.kafka#kafka-clients;3.4.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.5.0 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.5.0 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.slf4j#slf4j-api;2.0.7 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   11  |   0   |   0   |   0   ||   11  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-5f12a508-8efc-4ca7-ad80-bd774fa17858
# 	confs: [default]
# 	0 artifacts copied, 11 already retrieved (0kB/4ms)
# 25/03/22 21:40:59 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
print("🚀 Available Columns in parsed_df:")
print(parsed_df.columns)  # ✅ Check actual column names
# Out:
# 🚀 Available Columns in parsed_df:
# ['vendorid', 'pickup_datetime', 'dropoff_datetime', 'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'table_name', 'taxi_type', 'trip_duration', 'tip_ratio', 'toll_ratio', 'fare_per_mile', 'fare_per_passenger', 'duration_per_mile', 'duration_per_passenger']

# %% [markdown]
# ## 4.1 Calling the Predictive Model API and Storing Predictions in Redis
# Assume you have a Flask API running that returns fare predictions. Use Spark’s foreachBatch to call the API and store the prediction in Redis.

# %%
import redis
import json

r = redis.StrictRedis(host='localhost', port=6379, decode_responses=True)

def send_to_model(batch_df, batch_id):
    """Processes each batch in Spark Streaming, sends enhanced features to Flask API, and stores predictions in Redis."""
    
    for row in batch_df.toLocalIterator():  # ✅ Process row-by-row
        try:
            payload = {
                "trip_distance": row.trip_distance,
                "passenger_count": row.passenger_count,
                "extra": row.extra,
                "mta_tax": row.mta_tax,
                "tip_amount": row.tip_amount,
                "tolls_amount": row.tolls_amount,
                "improvement_surcharge": row.improvement_surcharge,
                "total_amount": row.total_amount,
                "tip_ratio": row.tip_ratio,
                "toll_ratio": row.toll_ratio,
                "fare_per_mile": row.fare_per_mile,
                "fare_per_passenger": row.fare_per_passenger,
                "duration_per_mile": row.duration_per_mile,
                "duration_per_passenger": row.duration_per_passenger
            }

            response = requests.post("http://localhost:5000/predict", json=payload)

            if response.status_code != 200:
                print(f"❌ API Error {response.status_code}: {response.text}")
                print(f"📤 Sent Payload: {json.dumps(payload, indent=2)}")  # ✅ Debugging
                continue

            prediction = response.json()

            # ✅ Ensure prediction keys exist
            if "fare_prediction" not in prediction or "duration_prediction" not in prediction:
                print(f"❌ Invalid API response: {response.text}")
                continue

            key = f"trip:{row.vendorid}:{row.trip_distance}"
            r.set(key, json.dumps(prediction))
            print(f"✅ Stored prediction: {key} -> {prediction}")

        except Exception as e:
            print(f"❌ Error processing row: {e}")


# ✅ Apply the Function to Stream
query = parsed_df.writeStream.foreachBatch(send_to_model).start()
query.awaitTermination()
# Out:
# 25/03/22 21:41:01 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /private/var/folders/4n/68l65j717mxb8994g_2bc9_00000gn/T/temporary-4f67aa93-637a-40dc-a01c-b4245ded4365. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 25/03/22 21:41:01 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 25/03/22 21:41:01 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# [Stage 0:>                                                          (0 + 1) / 1]
# ✅ Stored prediction: trip:2:0.98 -> {'duration_prediction': 0.715811550617218, 'fare_prediction': 10.063321113586426}
# ✅ Stored prediction: trip:2:5.99 -> {'duration_prediction': -0.06264559179544449, 'fare_prediction': 23.094005584716797}
# ✅ Stored prediction: trip:2:1.52 -> {'duration_prediction': 2.4805853366851807, 'fare_prediction': 9.90581226348877}
# ✅ Stored prediction: trip:2:0.0 -> {'duration_prediction': -0.36556288599967957, 'fare_prediction': -0.3430016040802002}
# ✅ Stored prediction: trip:2:0.0 -> {'duration_prediction': -0.18354009091854095, 'fare_prediction': 1.287048101425171}
# ✅ Stored prediction: trip:2:2.03 -> {'duration_prediction': 6.108088970184326, 'fare_prediction': 12.468304634094238}
# ✅ Stored prediction: trip:2:1.01 -> {'duration_prediction': 2.559443712234497, 'fare_prediction': 7.696784496307373}
# ✅ Stored prediction: trip:2:7.82 -> {'duration_prediction': -2.0602962970733643, 'fare_prediction': 35.03217697143555}
# ✅ Stored prediction: trip:2:0.48 -> {'duration_prediction': 0.6513500809669495, 'fare_prediction': 5.685603141784668}
# ✅ Stored prediction: trip:2:2.06 -> {'duration_prediction': 0.9004974365234375, 'fare_prediction': 11.802721977233887}
# ✅ Stored prediction: trip:2:1.65 -> {'duration_prediction': 1.3500964641571045, 'fare_prediction': 9.348899841308594}
# ✅ Stored prediction: trip:2:0.83 -> {'duration_prediction': 0.5198760032653809, 'fare_prediction': 9.2883882522583}
# ✅ Stored prediction: trip:2:0.55 -> {'duration_prediction': -0.1645970642566681, 'fare_prediction': 5.386940002441406}
# ✅ Stored prediction: trip:2:5.12 -> {'duration_prediction': -3.2361412048339844, 'fare_prediction': 26.427034378051758}
# ✅ Stored prediction: trip:2:4.09 -> {'duration_prediction': 0.2187563180923462, 'fare_prediction': 24.093114852905273}
# ✅ Stored prediction: trip:2:7.44 -> {'duration_prediction': -3.015000104904175, 'fare_prediction': 32.144222259521484}
# ✅ Stored prediction: trip:2:3.59 -> {'duration_prediction': 3.332935333251953, 'fare_prediction': 23.646486282348633}
# ✅ Stored prediction: trip:2:1.49 -> {'duration_prediction': 2.9717018604278564, 'fare_prediction': 10.233190536499023}
# ✅ Stored prediction: trip:2:1.35 -> {'duration_prediction': 0.6002384424209595, 'fare_prediction': 8.785958290100098}
# ✅ Stored prediction: trip:2:0.61 -> {'duration_prediction': 0.09628912061452866, 'fare_prediction': 5.879574775695801}
# ✅ Stored prediction: trip:2:6.06 -> {'duration_prediction': -2.620702028274536, 'fare_prediction': 28.23352813720703}
# ✅ Stored prediction: trip:2:0.44 -> {'duration_prediction': -0.3057931065559387, 'fare_prediction': 4.05952787399292}
# ✅ Stored prediction: trip:2:1.51 -> {'duration_prediction': 3.8141136169433594, 'fare_prediction': 9.4572114944458}
# ✅ Stored prediction: trip:2:0.98 -> {'duration_prediction': 2.9199838638305664, 'fare_prediction': 7.424101829528809}
# ✅ Stored prediction: trip:2:1.11 -> {'duration_prediction': 0.4762073755264282, 'fare_prediction': 6.977101802825928}
# ✅ Stored prediction: trip:2:2.02 -> {'duration_prediction': 0.9004974365234375, 'fare_prediction': 11.802721977233887}
# ✅ Stored prediction: trip:2:1.67 -> {'duration_prediction': 1.4651718139648438, 'fare_prediction': 9.61744499206543}
# ✅ Stored prediction: trip:2:2.01 -> {'duration_prediction': 0.9114272594451904, 'fare_prediction': 13.248360633850098}
# ✅ Stored prediction: trip:2:14.96 -> {'duration_prediction': 9.371744155883789, 'fare_prediction': 59.45002365112305}
# ✅ Stored prediction: trip:2:0.9 -> {'duration_prediction': 0.4250592589378357, 'fare_prediction': 7.289949417114258}
# ✅ Stored prediction: trip:2:0.98 -> {'duration_prediction': 1.4622925519943237, 'fare_prediction': 7.035029888153076}
# ✅ Stored prediction: trip:2:1.43 -> {'duration_prediction': 0.6700844168663025, 'fare_prediction': 9.960909843444824}
# ✅ Stored prediction: trip:2:1.94 -> {'duration_prediction': 1.4032105207443237, 'fare_prediction': 10.270426750183105}
# ✅ Stored prediction: trip:2:1.02 -> {'duration_prediction': 0.4908400774002075, 'fare_prediction': 6.801565170288086}
# ✅ Stored prediction: trip:2:1.28 -> {'duration_prediction': 0.20115399360656738, 'fare_prediction': 8.875871658325195}
# ✅ Stored prediction: trip:2:2.44 -> {'duration_prediction': 1.075280785560608, 'fare_prediction': 13.261957168579102}
# ✅ Stored prediction: trip:2:0.91 -> {'duration_prediction': 0.29333943128585815, 'fare_prediction': 7.148762226104736}
# ✅ Stored prediction: trip:2:9.8 -> {'duration_prediction': 1.0292333364486694, 'fare_prediction': 39.7711181640625}
# ✅ Stored prediction: trip:2:0.51 -> {'duration_prediction': -0.10187019407749176, 'fare_prediction': 5.519339084625244}
# ✅ Stored prediction: trip:2:0.8 -> {'duration_prediction': 0.0707542672753334, 'fare_prediction': 5.8560471534729}
# ✅ Stored prediction: trip:2:1.96 -> {'duration_prediction': 1.2952836751937866, 'fare_prediction': 12.988808631896973}
# ✅ Stored prediction: trip:2:3.91 -> {'duration_prediction': 0.9514852166175842, 'fare_prediction': 19.114553451538086}
# ✅ Stored prediction: trip:2:0.0 -> {'duration_prediction': -1.1458351612091064, 'fare_prediction': 0.9141354560852051}
# ✅ Stored prediction: trip:2:2.1 -> {'duration_prediction': 1.0643514394760132, 'fare_prediction': 11.802721977233887}
# ✅ Stored prediction: trip:2:11.02 -> {'duration_prediction': 1.8659793138504028, 'fare_prediction': 45.23323440551758}
# ✅ Stored prediction: trip:2:7.19 -> {'duration_prediction': -1.802781343460083, 'fare_prediction': 34.23103332519531}
# ✅ Stored prediction: trip:2:0.85 -> {'duration_prediction': 0.3590145707130432, 'fare_prediction': 6.780702590942383}
# ✅ Stored prediction: trip:2:4.7 -> {'duration_prediction': -0.09506312757730484, 'fare_prediction': 23.060623168945312}
# ✅ Stored prediction: trip:2:0.62 -> {'duration_prediction': 0.09628912061452866, 'fare_prediction': 5.879574775695801}
# ✅ Stored prediction: trip:1:0.9 -> {'duration_prediction': 0.11357247084379196, 'fare_prediction': 6.3427252769470215}
# ✅ Stored prediction: trip:1:1.5 -> {'duration_prediction': 1.2032196521759033, 'fare_prediction': 10.550658226013184}
# ✅ Stored prediction: trip:1:1.5 -> {'duration_prediction': 1.1070059537887573, 'fare_prediction': 9.896561622619629}
# ✅ Stored prediction: trip:2:0.56 -> {'duration_prediction': -0.28968358039855957, 'fare_prediction': 5.215150356292725}
# ✅ Stored prediction: trip:2:2.68 -> {'duration_prediction': 0.8374273180961609, 'fare_prediction': 16.072174072265625}
# ✅ Stored prediction: trip:2:2.24 -> {'duration_prediction': 1.577944278717041, 'fare_prediction': 12.969019889831543}
# ✅ Stored prediction: trip:2:4.07 -> {'duration_prediction': -0.048076122999191284, 'fare_prediction': 20.967803955078125}
# ✅ Stored prediction: trip:1:1.3 -> {'duration_prediction': 0.5619306564331055, 'fare_prediction': 8.56292724609375}
# ✅ Stored prediction: trip:1:1.2 -> {'duration_prediction': 0.4091434180736542, 'fare_prediction': 8.887866020202637}
# ✅ Stored prediction: trip:2:1.05 -> {'duration_prediction': 0.4762073755264282, 'fare_prediction': 7.049208164215088}
# ✅ Stored prediction: trip:2:4.33 -> {'duration_prediction': -0.06264559179544449, 'fare_prediction': 21.598392486572266}
# ✅ Stored prediction: trip:1:0.4 -> {'duration_prediction': -0.45439818501472473, 'fare_prediction': 4.098308086395264}
# ✅ Stored prediction: trip:1:2.3 -> {'duration_prediction': 2.0061588287353516, 'fare_prediction': 14.535829544067383}
# ✅ Stored prediction: trip:1:1.0 -> {'duration_prediction': 0.5268955230712891, 'fare_prediction': 8.647712707519531}
# ✅ Stored prediction: trip:1:1.3 -> {'duration_prediction': 0.30330368876457214, 'fare_prediction': 8.585054397583008}
# ✅ Stored prediction: trip:2:1.9 -> {'duration_prediction': 2.6151506900787354, 'fare_prediction': 11.020050048828125}
# ✅ Stored prediction: trip:2:2.2 -> {'duration_prediction': -0.3624858558177948, 'fare_prediction': 16.905445098876953}
# ✅ Stored prediction: trip:2:9.16 -> {'duration_prediction': 1.7283726930618286, 'fare_prediction': 37.08171844482422}
# ✅ Stored prediction: trip:2:5.68 -> {'duration_prediction': 0.43443435430526733, 'fare_prediction': 31.070110321044922}
# ✅ Stored prediction: trip:2:2.4 -> {'duration_prediction': 1.3079389333724976, 'fare_prediction': 16.86285400390625}
# ✅ Stored prediction: trip:2:3.12 -> {'duration_prediction': -0.42036280035972595, 'fare_prediction': 17.396921157836914}
# ✅ Stored prediction: trip:2:2.62 -> {'duration_prediction': 0.44716912508010864, 'fare_prediction': 14.730916976928711}
# ✅ Stored prediction: trip:2:2.0 -> {'duration_prediction': 1.5348844528198242, 'fare_prediction': 13.079412460327148}
# ✅ Stored prediction: trip:2:1.37 -> {'duration_prediction': 0.6700844168663025, 'fare_prediction': 8.871707916259766}
# ✅ Stored prediction: trip:2:1.18 -> {'duration_prediction': 2.826496124267578, 'fare_prediction': 8.56832218170166}
# ✅ Stored prediction: trip:1:3.5 -> {'duration_prediction': -0.6013509631156921, 'fare_prediction': 19.81230926513672}
# ✅ Stored prediction: trip:1:1.5 -> {'duration_prediction': 1.0648853778839111, 'fare_prediction': 9.085505485534668}
# ✅ Stored prediction: trip:2:4.91 -> {'duration_prediction': -2.0393178462982178, 'fare_prediction': 27.547155380249023}
# ✅ Stored prediction: trip:2:1.36 -> {'duration_prediction': 0.6343660950660706, 'fare_prediction': 9.99653434753418}
# ✅ Stored prediction: trip:2:1.0 -> {'duration_prediction': 0.6536448001861572, 'fare_prediction': 7.923335075378418}
# ✅ Stored prediction: trip:2:2.58 -> {'duration_prediction': 1.2642652988433838, 'fare_prediction': 13.258395195007324}
# ✅ Stored prediction: trip:2:0.43 -> {'duration_prediction': 0.03865008428692818, 'fare_prediction': 5.418484687805176}
# ✅ Stored prediction: trip:2:2.35 -> {'duration_prediction': 1.140430212020874, 'fare_prediction': 15.421740531921387}
# ✅ Stored prediction: trip:2:1.13 -> {'duration_prediction': 0.6440516114234924, 'fare_prediction': 8.181882858276367}
# ✅ Stored prediction: trip:2:1.73 -> {'duration_prediction': 1.1377546787261963, 'fare_prediction': 12.428442001342773}
# ✅ Stored prediction: trip:2:1.97 -> {'duration_prediction': 1.4032105207443237, 'fare_prediction': 10.270426750183105}
# ✅ Stored prediction: trip:2:6.82 -> {'duration_prediction': -3.0088753700256348, 'fare_prediction': 32.51945114135742}
# ✅ Stored prediction: trip:1:0.8 -> {'duration_prediction': -0.06472177058458328, 'fare_prediction': 6.168560981750488}
# ✅ Stored prediction: trip:2:2.71 -> {'duration_prediction': -0.3624858558177948, 'fare_prediction': 16.233177185058594}
# ✅ Stored prediction: trip:2:0.63 -> {'duration_prediction': 0.09628912061452866, 'fare_prediction': 5.879574775695801}
# ✅ Stored prediction: trip:1:4.6 -> {'duration_prediction': 1.1675959825515747, 'fare_prediction': 22.639171600341797}
# ✅ Stored prediction: trip:2:2.61 -> {'duration_prediction': 1.3079389333724976, 'fare_prediction': 16.881935119628906}
# ✅ Stored prediction: trip:2:1.83 -> {'duration_prediction': 0.4455118179321289, 'fare_prediction': 11.860310554504395}
# ✅ Stored prediction: trip:2:0.71 -> {'duration_prediction': -0.06564482301473618, 'fare_prediction': 5.58195161819458}
# ✅ Stored prediction: trip:2:4.79 -> {'duration_prediction': -2.2054970264434814, 'fare_prediction': 24.641277313232422}
# ✅ Stored prediction: trip:2:9.97 -> {'duration_prediction': 1.8020527362823486, 'fare_prediction': 43.298675537109375}
# ✅ Stored prediction: trip:2:2.16 -> {'duration_prediction': 0.03985191509127617, 'fare_prediction': 14.026331901550293}
# ✅ Stored prediction: trip:2:0.54 -> {'duration_prediction': -0.029095377773046494, 'fare_prediction': 5.423580169677734}
# ✅ Stored prediction: trip:2:2.52 -> {'duration_prediction': 1.577944278717041, 'fare_prediction': 13.080519676208496}
# ✅ Stored prediction: trip:2:5.28 -> {'duration_prediction': -2.8054730892181396, 'fare_prediction': 23.043825149536133}
# ✅ Stored prediction: trip:2:1.07 -> {'duration_prediction': 0.5128254294395447, 'fare_prediction': 6.887415409088135}
# ✅ Stored prediction: trip:2:2.28 -> {'duration_prediction': 1.140430212020874, 'fare_prediction': 15.600831985473633}
# ✅ Stored prediction: trip:2:3.32 -> {'duration_prediction': -3.2375693321228027, 'fare_prediction': 22.260513305664062}
# ✅ Stored prediction: trip:2:0.69 -> {'duration_prediction': -0.06564482301473618, 'fare_prediction': 5.84097146987915}
# ✅ Stored prediction: trip:2:1.81 -> {'duration_prediction': 0.30809521675109863, 'fare_prediction': 14.565680503845215}
# ✅ Stored prediction: trip:2:0.56 -> {'duration_prediction': -0.2727366089820862, 'fare_prediction': 5.198718070983887}
# ✅ Stored prediction: trip:2:1.88 -> {'duration_prediction': 0.45163655281066895, 'fare_prediction': 12.443678855895996}
# ✅ Stored prediction: trip:1:1.3 -> {'duration_prediction': 0.4380270838737488, 'fare_prediction': 8.953897476196289}
# ✅ Stored prediction: trip:1:2.6 -> {'duration_prediction': 1.0735101699829102, 'fare_prediction': 15.76407241821289}
# ✅ Stored prediction: trip:1:18.6 -> {'duration_prediction': 9.95874309539795, 'fare_prediction': 69.74119567871094}
# ✅ Stored prediction: trip:2:2.15 -> {'duration_prediction': 1.4652831554412842, 'fare_prediction': 10.840317726135254}
# ✅ Stored prediction: trip:2:0.52 -> {'duration_prediction': 0.24256959557533264, 'fare_prediction': 5.3615546226501465}
# ✅ Stored prediction: trip:2:7.31 -> {'duration_prediction': -1.9540108442306519, 'fare_prediction': 34.12858581542969}
# ✅ Stored prediction: trip:2:0.32 -> {'duration_prediction': 1.4494143724441528, 'fare_prediction': 7.849106311798096}
# ✅ Stored prediction: trip:2:1.51 -> {'duration_prediction': 3.9263689517974854, 'fare_prediction': 9.573880195617676}
# ✅ Stored prediction: trip:2:4.88 -> {'duration_prediction': -3.2375693321228027, 'fare_prediction': 25.93044662475586}
# ✅ Stored prediction: trip:2:3.22 -> {'duration_prediction': -0.3624858558177948, 'fare_prediction': 16.257720947265625}
# ✅ Stored prediction: trip:1:1.6 -> {'duration_prediction': 0.0677105262875557, 'fare_prediction': 11.113299369812012}
# ✅ Stored prediction: trip:1:1.0 -> {'duration_prediction': 0.5268955230712891, 'fare_prediction': 8.647712707519531}
# ✅ Stored prediction: trip:2:6.76 -> {'duration_prediction': -2.8905580043792725, 'fare_prediction': 28.248640060424805}
# ✅ Stored prediction: trip:2:2.42 -> {'duration_prediction': 1.3730446100234985, 'fare_prediction': 15.341976165771484}
# ✅ Stored prediction: trip:2:8.59 -> {'duration_prediction': 1.838575005531311, 'fare_prediction': 37.99495315551758}
# ✅ Stored prediction: trip:2:2.38 -> {'duration_prediction': 0.4719488024711609, 'fare_prediction': 15.477463722229004}
# ✅ Stored prediction: trip:1:2.4 -> {'duration_prediction': 0.27125808596611023, 'fare_prediction': 15.94040584564209}
# ✅ Stored prediction: trip:1:1.6 -> {'duration_prediction': 1.116244912147522, 'fare_prediction': 9.090112686157227}
# ✅ Stored prediction: trip:2:3.51 -> {'duration_prediction': -0.3624858558177948, 'fare_prediction': 17.462799072265625}
# ✅ Stored prediction: trip:2:1.16 -> {'duration_prediction': 0.715811550617218, 'fare_prediction': 9.068608283996582}
# ✅ Stored prediction: trip:2:1.11 -> {'duration_prediction': 0.49143344163894653, 'fare_prediction': 8.061769485473633}
# ✅ Stored prediction: trip:2:1.01 -> {'duration_prediction': 0.6700937747955322, 'fare_prediction': 6.86208438873291}
# ✅ Stored prediction: trip:2:1.87 -> {'duration_prediction': 0.9053025245666504, 'fare_prediction': 11.971322059631348}
# ✅ Stored prediction: trip:2:0.47 -> {'duration_prediction': -0.2803403437137604, 'fare_prediction': 4.901800632476807}
# ✅ Stored prediction: trip:2:1.4 -> {'duration_prediction': 4.046128273010254, 'fare_prediction': 9.484272003173828}
# ✅ Stored prediction: trip:2:0.31 -> {'duration_prediction': -0.06485556811094284, 'fare_prediction': 3.934670925140381}
# ✅ Stored prediction: trip:2:2.25 -> {'duration_prediction': -0.7945829033851624, 'fare_prediction': 15.506499290466309}
# ✅ Stored prediction: trip:2:0.88 -> {'duration_prediction': 2.401466131210327, 'fare_prediction': 7.858520984649658}
# ✅ Stored prediction: trip:2:1.77 -> {'duration_prediction': 1.3616119623184204, 'fare_prediction': 11.481284141540527}
# ✅ Stored prediction: trip:2:1.11 -> {'duration_prediction': 1.8559198379516602, 'fare_prediction': 7.710573673248291}
# ✅ Stored prediction: trip:2:2.66 -> {'duration_prediction': 0.5958276987075806, 'fare_prediction': 15.467248916625977}
# ✅ Stored prediction: trip:2:2.03 -> {'duration_prediction': 2.5542962551116943, 'fare_prediction': 11.2421236038208}
# ✅ Stored prediction: trip:2:2.39 -> {'duration_prediction': 2.5569562911987305, 'fare_prediction': 12.267630577087402}
# ✅ Stored prediction: trip:2:8.4 -> {'duration_prediction': 0.09234719723463058, 'fare_prediction': 36.60286331176758}
# ✅ Stored prediction: trip:2:0.56 -> {'duration_prediction': -0.2803403437137604, 'fare_prediction': 5.151307106018066}
# ✅ Stored prediction: trip:1:2.4 -> {'duration_prediction': -0.7448951005935669, 'fare_prediction': 16.003658294677734}
# ✅ Stored prediction: trip:1:2.2 -> {'duration_prediction': -0.7288694381713867, 'fare_prediction': 18.53023338317871}
# ✅ Stored prediction: trip:2:1.03 -> {'duration_prediction': 0.6530513763427734, 'fare_prediction': 7.432092666625977}
# ✅ Stored prediction: trip:2:0.9 -> {'duration_prediction': 0.8895192742347717, 'fare_prediction': 6.4385552406311035}
# ✅ Stored prediction: trip:2:7.55 -> {'duration_prediction': -1.9018521308898926, 'fare_prediction': 34.72026824951172}
# ✅ Stored prediction: trip:2:0.52 -> {'duration_prediction': -0.11840637773275375, 'fare_prediction': 5.147981643676758}
# ✅ Stored prediction: trip:2:4.34 -> {'duration_prediction': -2.8115978240966797, 'fare_prediction': 24.54143714904785}
# ✅ Stored prediction: trip:2:1.68 -> {'duration_prediction': 3.0947017669677734, 'fare_prediction': 10.392723083496094}
# ✅ Stored prediction: trip:2:1.74 -> {'duration_prediction': 1.469538688659668, 'fare_prediction': 10.310197830200195}
# ✅ Stored prediction: trip:2:5.04 -> {'duration_prediction': -2.8115978240966797, 'fare_prediction': 23.11827278137207}
# ✅ Stored prediction: trip:1:4.2 -> {'duration_prediction': -2.7559118270874023, 'fare_prediction': 21.862201690673828}
# ✅ Stored prediction: trip:2:0.75 -> {'duration_prediction': -0.06564482301473618, 'fare_prediction': 6.293669700622559}
# ✅ Stored prediction: trip:2:3.26 -> {'duration_prediction': -2.3238141536712646, 'fare_prediction': 21.86077117919922}
# ✅ Stored prediction: trip:2:0.39 -> {'duration_prediction': -0.01078193262219429, 'fare_prediction': 5.031006813049316}
# ✅ Stored prediction: trip:2:0.52 -> {'duration_prediction': -0.12774963676929474, 'fare_prediction': 5.211824893951416}
# ✅ Stored prediction: trip:2:1.05 -> {'duration_prediction': 3.251596450805664, 'fare_prediction': 8.67581844329834}
# ✅ Stored prediction: trip:2:1.41 -> {'duration_prediction': 0.6576923131942749, 'fare_prediction': 10.40539264678955}
# ✅ Stored prediction: trip:2:1.15 -> {'duration_prediction': 2.964647054672241, 'fare_prediction': 8.707244873046875}
# ✅ Stored prediction: trip:2:2.49 -> {'duration_prediction': 0.4719488024711609, 'fare_prediction': 14.577832221984863}
# ✅ Stored prediction: trip:2:4.21 -> {'duration_prediction': -0.06264559179544449, 'fare_prediction': 20.85700798034668}
# ✅ Stored prediction: trip:1:0.7 -> {'duration_prediction': 1.1774524450302124, 'fare_prediction': 5.75158166885376}
# ✅ Stored prediction: trip:2:21.56 -> {'duration_prediction': 11.456099510192871, 'fare_prediction': 72.40758514404297}
# ✅ Stored prediction: trip:2:4.8 -> {'duration_prediction': -2.8115978240966797, 'fare_prediction': 23.891874313354492}
# ✅ Stored prediction: trip:1:0.6 -> {'duration_prediction': -0.22920627892017365, 'fare_prediction': 5.218742847442627}
# ✅ Stored prediction: trip:1:2.1 -> {'duration_prediction': 0.2330813705921173, 'fare_prediction': 11.996996879577637}
# ✅ Stored prediction: trip:1:13.3 -> {'duration_prediction': 5.812649726867676, 'fare_prediction': 54.866573333740234}
# ✅ Stored prediction: trip:1:9.0 -> {'duration_prediction': 1.9161076545715332, 'fare_prediction': 36.60268020629883}
# ✅ Stored prediction: trip:2:0.59 -> {'duration_prediction': 0.08629752695560455, 'fare_prediction': 5.509128093719482}
# ✅ Stored prediction: trip:2:1.05 -> {'duration_prediction': 1.8823025226593018, 'fare_prediction': 8.149938583374023}
# ✅ Stored prediction: trip:2:0.7 -> {'duration_prediction': 0.9163509607315063, 'fare_prediction': 5.944806098937988}
# ✅ Stored prediction: trip:2:6.83 -> {'duration_prediction': 0.25988298654556274, 'fare_prediction': 34.24599075317383}
# ✅ Stored prediction: trip:2:1.64 -> {'duration_prediction': 2.280416965484619, 'fare_prediction': 9.929116249084473}
# ✅ Stored prediction: trip:2:6.35 -> {'duration_prediction': -2.8054730892181396, 'fare_prediction': 30.351787567138672}
# ✅ Stored prediction: trip:2:3.08 -> {'duration_prediction': 0.704606831073761, 'fare_prediction': 19.663997650146484}
# ✅ Stored prediction: trip:2:8.24 -> {'duration_prediction': -2.0907328128814697, 'fare_prediction': 34.795894622802734}
# ✅ Stored prediction: trip:1:2.0 -> {'duration_prediction': 1.192064881324768, 'fare_prediction': 10.612375259399414}
# ✅ Stored prediction: trip:2:5.99 -> {'duration_prediction': -2.0393178462982178, 'fare_prediction': 27.606151580810547}
# ✅ Stored prediction: trip:2:3.03 -> {'duration_prediction': -0.048076122999191284, 'fare_prediction': 21.03795051574707}
# ✅ Stored prediction: trip:2:4.21 -> {'duration_prediction': -0.35355162620544434, 'fare_prediction': 20.70703125}
# ✅ Stored prediction: trip:2:1.37 -> {'duration_prediction': -0.08682938665151596, 'fare_prediction': 14.558622360229492}
# ✅ Stored prediction: trip:2:0.0 -> {'duration_prediction': -0.07811524718999863, 'fare_prediction': 3.25551700592041}
# ✅ Stored prediction: trip:2:0.0 -> {'duration_prediction': -0.17006273567676544, 'fare_prediction': 2.296241521835327}
# ✅ Stored prediction: trip:2:6.56 -> {'duration_prediction': -1.7567328214645386, 'fare_prediction': 32.87293243408203}
# ✅ Stored prediction: trip:2:0.72 -> {'duration_prediction': -0.05804109945893288, 'fare_prediction': 5.981451988220215}
# ✅ Stored prediction: trip:2:0.87 -> {'duration_prediction': 0.8330817222595215, 'fare_prediction': 6.401220798492432}
# ✅ Stored prediction: trip:2:1.08 -> {'duration_prediction': 0.5109540820121765, 'fare_prediction': 6.887415409088135}
# ✅ Stored prediction: trip:2:2.06 -> {'duration_prediction': -0.4846446216106415, 'fare_prediction': 18.917051315307617}
# ✅ Stored prediction: trip:2:6.55 -> {'duration_prediction': -1.6984493732452393, 'fare_prediction': 35.54062271118164}
# ✅ Stored prediction: trip:1:4.4 -> {'duration_prediction': 0.22108221054077148, 'fare_prediction': 15.348409652709961}
# ✅ Stored prediction: trip:2:2.32 -> {'duration_prediction': 1.1991596221923828, 'fare_prediction': 14.635058403015137}
# ✅ Stored prediction: trip:1:3.7 -> {'duration_prediction': 0.9514852166175842, 'fare_prediction': 18.23809051513672}
# ✅ Stored prediction: trip:2:1.11 -> {'duration_prediction': 0.715811550617218, 'fare_prediction': 9.990876197814941}
# ✅ Stored prediction: trip:2:1.8 -> {'duration_prediction': -0.5324639081954956, 'fare_prediction': 14.917304992675781}
# ✅ Stored prediction: trip:2:1.69 -> {'duration_prediction': 1.2073793411254883, 'fare_prediction': 9.291202545166016}
# ✅ Stored prediction: trip:2:2.02 -> {'duration_prediction': 1.577209711074829, 'fare_prediction': 13.643011093139648}
# ✅ Stored prediction: trip:2:5.25 -> {'duration_prediction': -2.5209767818450928, 'fare_prediction': 30.083105087280273}
# ✅ Stored prediction: trip:2:1.34 -> {'duration_prediction': 0.05671200901269913, 'fare_prediction': 12.288275718688965}
# ✅ Stored prediction: trip:2:5.29 -> {'duration_prediction': -2.8054730892181396, 'fare_prediction': 28.7655029296875}
# ✅ Stored prediction: trip:1:1.4 -> {'duration_prediction': 0.416390061378479, 'fare_prediction': 5.862252712249756}
# ✅ Stored prediction: trip:2:3.42 -> {'duration_prediction': -0.2386072278022766, 'fare_prediction': 17.93648338317871}
# ✅ Stored prediction: trip:1:2.8 -> {'duration_prediction': 0.9410438537597656, 'fare_prediction': 15.948179244995117}
# ✅ Stored prediction: trip:2:4.75 -> {'duration_prediction': -2.620702028274536, 'fare_prediction': 31.1929931640625}
# ✅ Stored prediction: trip:2:0.94 -> {'duration_prediction': 2.9199838638305664, 'fare_prediction': 7.453019618988037}
# ✅ Stored prediction: trip:2:1.29 -> {'duration_prediction': 0.6064972877502441, 'fare_prediction': 9.99653434753418}
# ✅ Stored prediction: trip:2:0.71 -> {'duration_prediction': -0.06564482301473618, 'fare_prediction': 5.84097146987915}
# ✅ Stored prediction: trip:2:2.69 -> {'duration_prediction': -0.3624858558177948, 'fare_prediction': 16.233177185058594}
# ✅ Stored prediction: trip:2:3.02 -> {'duration_prediction': 1.1991596221923828, 'fare_prediction': 14.797066688537598}
# ✅ Stored prediction: trip:1:1.6 -> {'duration_prediction': 0.05356181412935257, 'fare_prediction': 10.766100883483887}
# ✅ Stored prediction: trip:2:4.94 -> {'duration_prediction': -2.8054730892181396, 'fare_prediction': 29.658893585205078}
# ✅ Stored prediction: trip:1:2.1 -> {'duration_prediction': 0.765019953250885, 'fare_prediction': 9.422746658325195}
# ✅ Stored prediction: trip:1:0.6 -> {'duration_prediction': -0.22025248408317566, 'fare_prediction': 5.15045690536499}
# ✅ Stored prediction: trip:2:1.12 -> {'duration_prediction': 1.0802029371261597, 'fare_prediction': 14.539024353027344}
# ✅ Stored prediction: trip:2:5.85 -> {'duration_prediction': -1.6984493732452393, 'fare_prediction': 35.48162841796875}
# ✅ Stored prediction: trip:2:0.88 -> {'duration_prediction': 0.24054446816444397, 'fare_prediction': 1.0402623414993286}
# ✅ Stored prediction: trip:2:1.03 -> {'duration_prediction': 0.9397662878036499, 'fare_prediction': 14.5272216796875}
# ✅ Stored prediction: trip:2:0.8 -> {'duration_prediction': 1.3877187967300415, 'fare_prediction': 6.898413181304932}
# ✅ Stored prediction: trip:2:3.83 -> {'duration_prediction': -0.3207912743091583, 'fare_prediction': 19.509939193725586}
# ✅ Stored prediction: trip:2:2.38 -> {'duration_prediction': -0.2056950032711029, 'fare_prediction': 19.547725677490234}
# ✅ Stored prediction: trip:2:1.41 -> {'duration_prediction': 2.536630153656006, 'fare_prediction': 9.738848686218262}
# ✅ Stored prediction: trip:2:4.68 -> {'duration_prediction': -2.8054730892181396, 'fare_prediction': 25.187725067138672}
# ✅ Stored prediction: trip:2:1.04 -> {'duration_prediction': 0.6530513763427734, 'fare_prediction': 7.432092666625977}
# ✅ Stored prediction: trip:2:0.62 -> {'duration_prediction': -0.07498804479837418, 'fare_prediction': 5.301547527313232}
# ✅ Stored prediction: trip:2:7.72 -> {'duration_prediction': -1.582512617111206, 'fare_prediction': 37.846866607666016}
# ✅ Stored prediction: trip:2:2.03 -> {'duration_prediction': 1.104392647743225, 'fare_prediction': 19.595592498779297}
# ✅ Stored prediction: trip:2:4.17 -> {'duration_prediction': -2.620702028274536, 'fare_prediction': 27.468515396118164}
# ✅ Stored prediction: trip:2:3.46 -> {'duration_prediction': 6.842672348022461, 'fare_prediction': 18.193435668945312}
# ✅ Stored prediction: trip:2:1.55 -> {'duration_prediction': 5.35146427154541, 'fare_prediction': 10.607549667358398}
# ✅ Stored prediction: trip:2:5.58 -> {'duration_prediction': -2.8054730892181396, 'fare_prediction': 25.216171264648438}
# ✅ Stored prediction: trip:2:1.59 -> {'duration_prediction': 0.5624151825904846, 'fare_prediction': 17.065956115722656}
# ✅ Stored prediction: trip:2:1.29 -> {'duration_prediction': 1.0881798267364502, 'fare_prediction': 13.57805347442627}
# ✅ Stored prediction: trip:2:0.74 -> {'duration_prediction': 0.11880411952733994, 'fare_prediction': 7.107667922973633}
# ✅ Stored prediction: trip:1:1.1 -> {'duration_prediction': 2.0139503479003906, 'fare_prediction': 7.221405029296875}
# ✅ Stored prediction: trip:2:0.57 -> {'duration_prediction': -0.16288664937019348, 'fare_prediction': 5.339820861816406}
# ✅ Stored prediction: trip:2:1.78 -> {'duration_prediction': 2.342162609100342, 'fare_prediction': 13.283782958984375}
# ✅ Stored prediction: trip:1:11.3 -> {'duration_prediction': 2.9239275455474854, 'fare_prediction': 45.18865203857422}
# ✅ Stored prediction: trip:2:0.63 -> {'duration_prediction': 0.3624453842639923, 'fare_prediction': 6.641465187072754}
# ✅ Stored prediction: trip:2:1.02 -> {'duration_prediction': 1.0876874923706055, 'fare_prediction': 11.3753023147583}
# ✅ Stored prediction: trip:2:2.06 -> {'duration_prediction': 1.3014296293258667, 'fare_prediction': 12.125372886657715}
# ✅ Stored prediction: trip:2:3.29 -> {'duration_prediction': 0.9628965258598328, 'fare_prediction': 18.37491226196289}
# ✅ Stored prediction: trip:2:0.69 -> {'duration_prediction': -0.07284370809793472, 'fare_prediction': 5.900076389312744}
# ✅ Stored prediction: trip:2:14.49 -> {'duration_prediction': 5.42725944519043, 'fare_prediction': 58.68369674682617}
# ✅ Stored prediction: trip:2:2.21 -> {'duration_prediction': 1.3730446100234985, 'fare_prediction': 15.372223854064941}
# ✅ Stored prediction: trip:2:4.54 -> {'duration_prediction': 0.013716000132262707, 'fare_prediction': 23.740386962890625}
# ✅ Stored prediction: trip:2:2.9 -> {'duration_prediction': 0.4719488024711609, 'fare_prediction': 14.667717933654785}
# ✅ Stored prediction: trip:2:2.05 -> {'duration_prediction': 2.6455063819885254, 'fare_prediction': 11.6117582321167}
# ✅ Stored prediction: trip:2:1.22 -> {'duration_prediction': 0.5209951400756836, 'fare_prediction': 8.15156364440918}
# ✅ Stored prediction: trip:2:3.99 -> {'duration_prediction': -2.8054730892181396, 'fare_prediction': 25.153610229492188}
# ✅ Stored prediction: trip:2:5.06 -> {'duration_prediction': -1.7506080865859985, 'fare_prediction': 33.93629837036133}
# ✅ Stored prediction: trip:2:1.38 -> {'duration_prediction': 0.4884319603443146, 'fare_prediction': 1.7593437433242798}
# ✅ Stored prediction: trip:2:1.38 -> {'duration_prediction': 0.5316339135169983, 'fare_prediction': 7.622525691986084}
# ✅ Stored prediction: trip:2:1.58 -> {'duration_prediction': 1.324841022491455, 'fare_prediction': 12.158088684082031}
# ✅ Stored prediction: trip:2:1.15 -> {'duration_prediction': 0.6440516114234924, 'fare_prediction': 8.153009414672852}
# ✅ Stored prediction: trip:2:1.23 -> {'duration_prediction': 3.365152597427368, 'fare_prediction': 9.340383529663086}
# ✅ Stored prediction: trip:2:3.91 -> {'duration_prediction': -2.8115978240966797, 'fare_prediction': 23.828474044799805}
# ✅ Stored prediction: trip:2:1.01 -> {'duration_prediction': 0.5389676094055176, 'fare_prediction': 8.772997856140137}
# ✅ Stored prediction: trip:2:2.56 -> {'duration_prediction': 3.038071870803833, 'fare_prediction': 17.42319679260254}
# ✅ Stored prediction: trip:2:4.51 -> {'duration_prediction': -0.22029554843902588, 'fare_prediction': 20.019615173339844}
# ✅ Stored prediction: trip:1:1.9 -> {'duration_prediction': 3.1022284030914307, 'fare_prediction': 10.58879566192627}
# ✅ Stored prediction: trip:1:3.2 -> {'duration_prediction': 0.27125808596611023, 'fare_prediction': 16.413890838623047}
# ✅ Stored prediction: trip:2:0.78 -> {'duration_prediction': 0.08565182238817215, 'fare_prediction': 6.151813507080078}
# ✅ Stored prediction: trip:2:2.23 -> {'duration_prediction': -0.138512521982193, 'fare_prediction': 20.303016662597656}
# ✅ Stored prediction: trip:2:1.31 -> {'duration_prediction': 0.8395739197731018, 'fare_prediction': 10.077960014343262}
# ✅ Stored prediction: trip:2:2.8 -> {'duration_prediction': -0.22642022371292114, 'fare_prediction': 19.793926239013672}
# ✅ Stored prediction: trip:2:1.35 -> {'duration_prediction': 0.5165016055107117, 'fare_prediction': 13.241331100463867}
# ✅ Stored prediction: trip:2:3.28 -> {'duration_prediction': -0.048076122999191284, 'fare_prediction': 20.99445343017578}
# ✅ Stored prediction: trip:2:3.41 -> {'duration_prediction': 5.595556259155273, 'fare_prediction': 18.92110252380371}
# ✅ Stored prediction: trip:1:1.7 -> {'duration_prediction': 0.06922736018896103, 'fare_prediction': 12.005167007446289}
# ✅ Stored prediction: trip:2:1.4 -> {'duration_prediction': 0.9808850288391113, 'fare_prediction': 10.830594062805176}
# ✅ Stored prediction: trip:2:1.03 -> {'duration_prediction': 2.0112993717193604, 'fare_prediction': 11.46230697631836}
# ✅ Stored prediction: trip:2:1.54 -> {'duration_prediction': 1.2270971536636353, 'fare_prediction': 9.2382230758667}
# ✅ Stored prediction: trip:2:4.03 -> {'duration_prediction': -2.6871559619903564, 'fare_prediction': 27.095680236816406}
# ✅ Stored prediction: trip:2:2.02 -> {'duration_prediction': 0.962202250957489, 'fare_prediction': 18.187673568725586}
# ✅ Stored prediction: trip:1:1.8 -> {'duration_prediction': 1.1948187351226807, 'fare_prediction': 10.171826362609863}
# ✅ Stored prediction: trip:1:1.2 -> {'duration_prediction': 1.5220485925674438, 'fare_prediction': 8.259206771850586}
# ✅ Stored prediction: trip:1:1.6 -> {'duration_prediction': 3.162909984588623, 'fare_prediction': 9.771190643310547}
# ✅ Stored prediction: trip:2:0.87 -> {'duration_prediction': 0.29333943128585815, 'fare_prediction': 7.332437992095947}
# ✅ Stored prediction: trip:1:2.8 -> {'duration_prediction': 0.9514852166175842, 'fare_prediction': 20.260814666748047}
# ✅ Stored prediction: trip:2:0.34 -> {'duration_prediction': -0.08858252316713333, 'fare_prediction': 4.131148815155029}
# ✅ Stored prediction: trip:2:1.31 -> {'duration_prediction': 2.974713087081909, 'fare_prediction': 8.538617134094238}
# ✅ Stored prediction: trip:2:1.67 -> {'duration_prediction': 5.678893089294434, 'fare_prediction': 13.147469520568848}
# ✅ Stored prediction: trip:2:2.87 -> {'duration_prediction': -0.3624858558177948, 'fare_prediction': 16.233177185058594}
# ✅ Stored prediction: trip:2:1.83 -> {'duration_prediction': 1.3496074676513672, 'fare_prediction': 10.343035697937012}
# ✅ Stored prediction: trip:2:2.06 -> {'duration_prediction': 2.6455063819885254, 'fare_prediction': 12.683079719543457}
# ✅ Stored prediction: trip:2:2.94 -> {'duration_prediction': 6.550230979919434, 'fare_prediction': 16.650650024414062}
# ✅ Stored prediction: trip:2:1.21 -> {'duration_prediction': 0.5209951400756836, 'fare_prediction': 8.626751899719238}
# ✅ Stored prediction: trip:2:2.08 -> {'duration_prediction': 1.4229607582092285, 'fare_prediction': 15.23674488067627}
# ✅ Stored prediction: trip:2:1.67 -> {'duration_prediction': 0.3421172499656677, 'fare_prediction': 12.42619514465332}
# ✅ Stored prediction: trip:1:1.1 -> {'duration_prediction': 1.645105004310608, 'fare_prediction': 7.844205379486084}
# ✅ Stored prediction: trip:2:0.0 -> {'duration_prediction': -0.36556288599967957, 'fare_prediction': -0.3430016040802002}
# ✅ Stored prediction: trip:2:0.0 -> {'duration_prediction': -0.18354009091854095, 'fare_prediction': 1.287048101425171}
# ✅ Stored prediction: trip:2:1.42 -> {'duration_prediction': 3.8300867080688477, 'fare_prediction': 9.988998413085938}
# ✅ Stored prediction: trip:2:2.3 -> {'duration_prediction': 2.7014963626861572, 'fare_prediction': 16.101421356201172}
# ✅ Stored prediction: trip:2:2.17 -> {'duration_prediction': 0.4719488024711609, 'fare_prediction': 15.507711410522461}
# ✅ Stored prediction: trip:2:3.51 -> {'duration_prediction': -0.29456251859664917, 'fare_prediction': 17.38184356689453}
# ✅ Stored prediction: trip:1:2.4 -> {'duration_prediction': -0.8007075786590576, 'fare_prediction': 12.633759498596191}
# ✅ Stored prediction: trip:2:2.48 -> {'duration_prediction': -0.3624858558177948, 'fare_prediction': 16.90399932861328}
# ✅ Stored prediction: trip:1:2.6 -> {'duration_prediction': -0.5534802675247192, 'fare_prediction': 18.32072639465332}
# ✅ Stored prediction: trip:2:1.22 -> {'duration_prediction': 0.5557418465614319, 'fare_prediction': 8.539186477661133}
# ✅ Stored prediction: trip:1:2.1 -> {'duration_prediction': 2.2002811431884766, 'fare_prediction': 12.21376895904541}
# ✅ Stored prediction: trip:2:1.22 -> {'duration_prediction': 0.5537684559822083, 'fare_prediction': 8.712501525878906}
# ✅ Stored prediction: trip:2:1.25 -> {'duration_prediction': 0.5771037340164185, 'fare_prediction': 9.982723236083984}
# ✅ Stored prediction: trip:2:7.22 -> {'duration_prediction': 0.25988298654556274, 'fare_prediction': 30.976680755615234}
# ✅ Stored prediction: trip:1:3.2 -> {'duration_prediction': 0.12542182207107544, 'fare_prediction': 24.734085083007812}
# ✅ Stored prediction: trip:1:0.1 -> {'duration_prediction': -0.5338152050971985, 'fare_prediction': 4.327797889709473}
# ✅ Stored prediction: trip:2:1.15 -> {'duration_prediction': 0.6811137199401855, 'fare_prediction': 9.019304275512695}
# ✅ Stored prediction: trip:2:2.55 -> {'duration_prediction': 0.4719488024711609, 'fare_prediction': 15.48147964477539}
# ✅ Stored prediction: trip:2:2.09 -> {'duration_prediction': 0.45163655281066895, 'fare_prediction': 12.381611824035645}
# ✅ Stored prediction: trip:2:1.43 -> {'duration_prediction': 0.6700844168663025, 'fare_prediction': 8.834395408630371}
# ✅ Stored prediction: trip:1:4.0 -> {'duration_prediction': -3.177417278289795, 'fare_prediction': 28.91702651977539}
# ✅ Stored prediction: trip:2:17.43 -> {'duration_prediction': 9.265482902526855, 'fare_prediction': 71.24219512939453}
# ✅ Stored prediction: trip:1:0.9 -> {'duration_prediction': 1.0747716426849365, 'fare_prediction': 6.521388530731201}
# ✅ Stored prediction: trip:1:2.2 -> {'duration_prediction': 1.147452712059021, 'fare_prediction': 14.379611015319824}
# ✅ Stored prediction: trip:1:1.6 -> {'duration_prediction': 1.128972053527832, 'fare_prediction': 9.934676170349121}
# ✅ Stored prediction: trip:2:2.1 -> {'duration_prediction': 1.075280785560608, 'fare_prediction': 13.21811294555664}
# ✅ Stored prediction: trip:2:2.36 -> {'duration_prediction': 1.075280785560608, 'fare_prediction': 13.186293601989746}
# ✅ Stored prediction: trip:2:0.0 -> {'duration_prediction': -0.4113866984844208, 'fare_prediction': 84.8213882446289}
# ✅ Stored prediction: trip:1:1.3 -> {'duration_prediction': -0.2009291648864746, 'fare_prediction': 15.503707885742188}
# ✅ Stored prediction: trip:1:2.0 -> {'duration_prediction': 1.2782522439956665, 'fare_prediction': 12.056476593017578}
# ✅ Stored prediction: trip:2:1.46 -> {'duration_prediction': 3.0096895694732666, 'fare_prediction': 12.268379211425781}
# ✅ Stored prediction: trip:2:1.04 -> {'duration_prediction': 1.8619341850280762, 'fare_prediction': 8.664018630981445}
# ✅ Stored prediction: trip:2:6.94 -> {'duration_prediction': -1.4823517799377441, 'fare_prediction': 35.52506637573242}
# ✅ Stored prediction: trip:2:0.77 -> {'duration_prediction': 1.1553473472595215, 'fare_prediction': 7.265722274780273}
# ✅ Stored prediction: trip:2:1.65 -> {'duration_prediction': 0.48565855622291565, 'fare_prediction': 11.411164283752441}
# ✅ Stored prediction: trip:2:0.79 -> {'duration_prediction': 0.9127129316329956, 'fare_prediction': 13.268583297729492}
# ✅ Stored prediction: trip:1:0.5 -> {'duration_prediction': -0.19130665063858032, 'fare_prediction': 5.236537456512451}
# ✅ Stored prediction: trip:2:0.64 -> {'duration_prediction': 0.3065192699432373, 'fare_prediction': 5.420782089233398}
# ✅ Stored prediction: trip:2:1.71 -> {'duration_prediction': 2.119344472885132, 'fare_prediction': 13.225312232971191}
# ✅ Stored prediction: trip:2:2.9 -> {'duration_prediction': 0.5094861388206482, 'fare_prediction': 36.651432037353516}
# ✅ Stored prediction: trip:2:2.43 -> {'duration_prediction': 1.0691560506820679, 'fare_prediction': 12.574213981628418}
# ✅ Stored prediction: trip:2:6.15 -> {'duration_prediction': -2.949833393096924, 'fare_prediction': 27.934005737304688}
# ✅ Stored prediction: trip:2:0.73 -> {'duration_prediction': 2.1639726161956787, 'fare_prediction': 8.73897647857666}
# ✅ Stored prediction: trip:2:1.02 -> {'duration_prediction': 1.8655130863189697, 'fare_prediction': 7.497406482696533}
# ✅ Stored prediction: trip:2:2.05 -> {'duration_prediction': 1.2091906070709229, 'fare_prediction': 14.531383514404297}
# ✅ Stored prediction: trip:2:1.31 -> {'duration_prediction': 0.6343660950660706, 'fare_prediction': 9.229259490966797}
# ✅ Stored prediction: trip:2:0.67 -> {'duration_prediction': -0.03814581781625748, 'fare_prediction': 5.700236797332764}
# ✅ Stored prediction: trip:2:2.13 -> {'duration_prediction': -0.3027818202972412, 'fare_prediction': 17.547948837280273}
# ✅ Stored prediction: trip:2:0.97 -> {'duration_prediction': 1.2945001125335693, 'fare_prediction': 10.951292991638184}
# ✅ Stored prediction: trip:1:0.1 -> {'duration_prediction': -0.3926270306110382, 'fare_prediction': 4.026615619659424}
# ✅ Stored prediction: trip:2:1.59 -> {'duration_prediction': 1.1357393264770508, 'fare_prediction': 9.188070297241211}
# ✅ Stored prediction: trip:2:1.06 -> {'duration_prediction': 0.715811550617218, 'fare_prediction': 10.033867835998535}
# ✅ Stored prediction: trip:2:4.64 -> {'duration_prediction': 0.13873150944709778, 'fare_prediction': 26.44091033935547}
# ✅ Stored prediction: trip:2:0.44 -> {'duration_prediction': -0.15088368952274323, 'fare_prediction': 4.754526615142822}
# ✅ Stored prediction: trip:2:1.5 -> {'duration_prediction': -0.3242584764957428, 'fare_prediction': 16.755292892456055}
# ✅ Stored prediction: trip:2:0.82 -> {'duration_prediction': 0.08565182238817215, 'fare_prediction': 6.280315399169922}
# ✅ Stored prediction: trip:2:1.38 -> {'duration_prediction': 3.5348665714263916, 'fare_prediction': 9.785947799682617}
# ✅ Stored prediction: trip:2:7.23 -> {'duration_prediction': -3.0088753700256348, 'fare_prediction': 32.58489227294922}
# ✅ Stored prediction: trip:2:1.25 -> {'duration_prediction': 3.0881872177124023, 'fare_prediction': 9.327340126037598}
# ✅ Stored prediction: trip:2:4.12 -> {'duration_prediction': 5.808683395385742, 'fare_prediction': 22.101505279541016}
# ✅ Stored prediction: trip:2:2.13 -> {'duration_prediction': -0.29665714502334595, 'fare_prediction': 18.248046875}
# ✅ Stored prediction: trip:1:2.5 -> {'duration_prediction': 2.0653305053710938, 'fare_prediction': 14.2514009475708}
# ✅ Stored prediction: trip:2:1.4 -> {'duration_prediction': 0.07510445266962051, 'fare_prediction': 15.362945556640625}
# ✅ Stored prediction: trip:2:16.79 -> {'duration_prediction': 6.0649189949035645, 'fare_prediction': 64.8421859741211}
# ✅ Stored prediction: trip:1:2.1 -> {'duration_prediction': 1.3110648393630981, 'fare_prediction': 11.992947578430176}
# ✅ Stored prediction: trip:2:8.24 -> {'duration_prediction': -2.2206199169158936, 'fare_prediction': 33.595001220703125}
# ✅ Stored prediction: trip:2:0.96 -> {'duration_prediction': 2.331990957260132, 'fare_prediction': 7.37362813949585}
# ✅ Stored prediction: trip:2:1.41 -> {'duration_prediction': 6.266514778137207, 'fare_prediction': 12.83706283569336}
# ✅ Stored prediction: trip:2:1.64 -> {'duration_prediction': 5.017714500427246, 'fare_prediction': 10.766828536987305}
# ✅ Stored prediction: trip:1:0.4 -> {'duration_prediction': 0.01197610143572092, 'fare_prediction': 14.927889823913574}
# ✅ Stored prediction: trip:2:1.35 -> {'duration_prediction': -0.6320399641990662, 'fare_prediction': 17.80820083618164}
# ✅ Stored prediction: trip:2:1.98 -> {'duration_prediction': 0.46578526496887207, 'fare_prediction': 12.413431167602539}
# ✅ Stored prediction: trip:2:6.54 -> {'duration_prediction': 5.1784749031066895, 'fare_prediction': 30.35244369506836}
# ✅ Stored prediction: trip:2:3.08 -> {'duration_prediction': -0.2386072278022766, 'fare_prediction': 19.520639419555664}
# ✅ Stored prediction: trip:1:2.0 -> {'duration_prediction': 0.10740437358617783, 'fare_prediction': 16.410913467407227}
# ✅ Stored prediction: trip:2:0.31 -> {'duration_prediction': -0.20301343500614166, 'fare_prediction': 3.3686587810516357}
# ✅ Stored prediction: trip:2:1.49 -> {'duration_prediction': 3.7162280082702637, 'fare_prediction': 9.108487129211426}
# ✅ Stored prediction: trip:2:3.9 -> {'duration_prediction': 4.299291610717773, 'fare_prediction': 20.87394142150879}
# ✅ Stored prediction: trip:2:0.92 -> {'duration_prediction': 0.24690407514572144, 'fare_prediction': 5.779109477996826}
# ✅ Stored prediction: trip:2:0.72 -> {'duration_prediction': -0.07498804479837418, 'fare_prediction': 5.614884376525879}
# ✅ Stored prediction: trip:2:1.08 -> {'duration_prediction': 0.47680073976516724, 'fare_prediction': 7.733989238739014}
# ✅ Stored prediction: trip:2:7.07 -> {'duration_prediction': -3.0088753700256348, 'fare_prediction': 28.284391403198242}
# ✅ Stored prediction: trip:2:0.56 -> {'duration_prediction': -0.29517146944999695, 'fare_prediction': 5.108737945556641}
# ✅ Stored prediction: trip:2:3.13 -> {'duration_prediction': 0.4719488024711609, 'fare_prediction': 15.992171287536621}
# ✅ Stored prediction: trip:2:5.72 -> {'duration_prediction': 6.76865816116333, 'fare_prediction': 27.87989616394043}
# ✅ Stored prediction: trip:2:3.96 -> {'duration_prediction': 2.3722500801086426, 'fare_prediction': 17.696516036987305}
# ✅ Stored prediction: trip:2:2.41 -> {'duration_prediction': 2.646200656890869, 'fare_prediction': 12.81209659576416}
# ✅ Stored prediction: trip:2:1.84 -> {'duration_prediction': 1.5468541383743286, 'fare_prediction': 16.63042449951172}
# ✅ Stored prediction: trip:2:4.98 -> {'duration_prediction': -0.048076122999191284, 'fare_prediction': 23.555479049682617}
# ✅ Stored prediction: trip:2:1.88 -> {'duration_prediction': 1.0942296981811523, 'fare_prediction': 11.453018188476562}
# ✅ Stored prediction: trip:2:0.57 -> {'duration_prediction': -0.07471665740013123, 'fare_prediction': 4.973179340362549}
# ✅ Stored prediction: trip:2:0.72 -> {'duration_prediction': -0.16288664937019348, 'fare_prediction': 5.391291618347168}
# ✅ Stored prediction: trip:2:2.19 -> {'duration_prediction': 4.956967830657959, 'fare_prediction': 12.1939058303833}
# ✅ Stored prediction: trip:2:1.17 -> {'duration_prediction': 0.5389676094055176, 'fare_prediction': 8.416391372680664}
# ✅ Stored prediction: trip:2:5.5 -> {'duration_prediction': -0.8507205843925476, 'fare_prediction': 44.8548583984375}
# ✅ Stored prediction: trip:2:4.39 -> {'duration_prediction': 0.7717893123626709, 'fare_prediction': 21.255666732788086}
# ✅ Stored prediction: trip:2:0.59 -> {'duration_prediction': -0.06210971996188164, 'fare_prediction': 4.79998254776001}
# ✅ Stored prediction: trip:2:0.0 -> {'duration_prediction': -0.12807975709438324, 'fare_prediction': 4.864267826080322}
# ✅ Stored prediction: trip:2:2.04 -> {'duration_prediction': 0.9179831147193909, 'fare_prediction': 11.802721977233887}
# ✅ Stored prediction: trip:2:0.83 -> {'duration_prediction': 0.078202985227108, 'fare_prediction': 6.063601016998291}
# ✅ Stored prediction: trip:1:2.4 -> {'duration_prediction': 2.1467807292938232, 'fare_prediction': 17.400583267211914}
# ✅ Stored prediction: trip:2:2.45 -> {'duration_prediction': 1.4652831554412842, 'fare_prediction': 12.31727123260498}
# ✅ Stored prediction: trip:2:1.99 -> {'duration_prediction': 1.1245852708816528, 'fare_prediction': 10.800586700439453}
# ✅ Stored prediction: trip:2:1.19 -> {'duration_prediction': 0.4159110188484192, 'fare_prediction': 8.416391372680664}
# ✅ Stored prediction: trip:2:15.03 -> {'duration_prediction': 5.142235279083252, 'fare_prediction': 59.074771881103516}
# ✅ Stored prediction: trip:2:1.37 -> {'duration_prediction': 2.971583127975464, 'fare_prediction': 8.547296524047852}
# ✅ Stored prediction: trip:2:2.43 -> {'duration_prediction': 1.4611105918884277, 'fare_prediction': 14.52388858795166}
# ✅ Stored prediction: trip:2:1.84 -> {'duration_prediction': 1.0942296981811523, 'fare_prediction': 11.453018188476562}
# ...
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/03/23 04:31:18 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:572)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:358)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1570)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@192.168.0.101:55057
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/03/23 04:31:18 ERROR Executor: Exit as unable to send heartbeats to driver more than 60 times
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/py39/lib/python3.9/site-packages/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/py39/lib/python3.9/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/opt/anaconda3/envs/py39/lib/python3.9/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# Cell In[4], line 52
#      50 # ✅ Apply the Function to Stream
#      51 query = parsed_df.writeStream.foreachBatch(send_to_model).start()
# ---> 52 query.awaitTermination()
#
# File /opt/anaconda3/envs/py39/lib/python3.9/site-packages/pyspark/sql/streaming/query.py:221, in StreamingQuery.awaitTermination(self, timeout)
#     219     return self._jsq.awaitTermination(int(timeout * 1000))
#     220 else:
# --> 221     return self._jsq.awaitTermination()
#
# File /opt/anaconda3/envs/py39/lib/python3.9/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /opt/anaconda3/envs/py39/lib/python3.9/site-packages/pyspark/errors/exceptions/captured.py:179, in capture_sql_exception.<locals>.deco(*a, **kw)
#     177 def deco(*a: Any, **kw: Any) -> Any:
#     178     try:
# --> 179         return f(*a, **kw)
#     180     except Py4JJavaError as e:
#     181         converted = convert_exception(e.java_exception)
#
# File /opt/anaconda3/envs/py39/lib/python3.9/site-packages/py4j/protocol.py:334, in get_return_value(answer, gateway_client, target_id, name)
#     330             raise Py4JError(
#     331                 "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332                 format(target_id, ".", name, value))
#     333     else:
# --> 334         raise Py4JError(
#     335             "An error occurred while calling {0}{1}{2}".
#     336             format(target_id, ".", name))
#     337 else:
#     338     type = answer[1]
#
# Py4JError: An error occurred while calling o122.awaitTermination
